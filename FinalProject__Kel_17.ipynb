# %% [markdown]
# # ***Proyek Analisis Data: Rental DVD***
# ## **Muslim Milennials Bootcamp Batch 3: Kelompok 17**

# %% [markdown]
# ## **Menentukan Pertanyaan Analisis**

# %% [markdown]
# - Film apa yang paling laris dirental?
# -  mana yang melakukan rental paling banyak?
# - Genre apa yang paling diminati?
# - Berapa rata-rata penghasilan setiap film?
# - Berapa lama total rental setiap film?

# %% [markdown]
# ## **Import Library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import os

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# ## **Gathering Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Akses direktori di Google Drive
directory_path = '/content/drive/MyDrive/MMB'

# %%
rentaldvd3_df = pd.read_csv('/content/drive/MyDrive/MMB/dvdrental3_db.csv', delimiter=';')
rentaldvd3_df.head()
# Out:
#               title                                        description  \
# 0  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 2  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 3  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 4  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
#
#    release_year  rental_duration  rental_rate  length  replacement_cost  \
# 0        2006.0              6.0         0.99    86.0             20.99
# 1        2006.0              6.0         0.99    86.0             20.99
# 2        2006.0              6.0         0.99    86.0             20.99
# 3        2006.0              6.0         0.99    86.0             20.99
# 4        2006.0              6.0         0.99    86.0             20.99
#
#   rating                        special_features  \
# 0     PG  {"Deleted Scenes","Behind the Scenes"}
# 1     PG  {"Deleted Scenes","Behind the Scenes"}
# 2     PG  {"Deleted Scenes","Behind the Scenes"}
# 3     PG  {"Deleted Scenes","Behind the Scenes"}
# 4     PG  {"Deleted Scenes","Behind the Scenes"}
#
#                                             fulltext  ... create_date active  \
# 0  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 1  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 2  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 3  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 4  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
#
#   payment_id amount                payment_date                       address  \
# 0    19665.0   3.99  2007-03-21 19:56:09.996577           600 Bradford Street
# 1    21895.0   3.99  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor
# 2    27023.0   0.99  2007-04-08 17:31:41.996577         287 Cuautla Boulevard
# 3    19665.0   3.99  2007-03-21 19:56:09.996577           600 Bradford Street
# 4    21895.0   3.99  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor
#
#            district    city  country              language
# 0  East Azerbaidzan  Tabriz     Iran  English
# 1             Sivas   Sivas   Turkey  English
# 2        Chuquisaca   Sucre  Bolivia  English
# 3  East Azerbaidzan  Tabriz     Iran  English
# 4             Sivas   Sivas   Turkey  English
#
# [5 rows x 25 columns]

# %%
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        data = pd.read_csv(file_path, delimiter=';')
        print(f"Loaded {filename} with shape {data.shape}")
# Out:
# Loaded dvdrental1_db.csv with shape (80115, 10)
# Loaded dvdrental3_db.csv with shape (88280, 25)

# %% [markdown]
# ## **Assessing Data**

# %%
rentaldvd3_df.info()
rentaldvd3_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88280 entries, 0 to 88279
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             88270 non-null  object
#  1   description       88270 non-null  object
#  2   release_year      88270 non-null  float64
#  3   rental_duration   88270 non-null  float64
#  4   rental_rate       88270 non-null  float64
#  5   length            88270 non-null  float64
#  6   replacement_cost  88270 non-null  float64
#  7   rating            88270 non-null  object
#  8   special_features  88270 non-null  object
#  9   fulltext          88270 non-null  object
#  10  first_name        88230 non-null  object
#  11  last_name         88230 non-null  object
#  12  name              88270 non-null  object
#  13  first_name.1      88044 non-null  object
#  14  last_name.1       88044 non-null  object
#  15  create_date       88044 non-null  object
#  16  active            88044 non-null  float64
#  17  payment_id        80153 non-null  float64
#  18  amount            80153 non-null  float64
#  19  payment_date      80153 non-null  object
#  20  address           88048 non-null  object
#  21  district          87488 non-null  object
#  22  city              88049 non-null  object
#  23  country           88049 non-null  object
#  24  language          88275 non-null  object
# dtypes: float64(8), object(17)
# memory usage: 16.8+ MB
# title                 10
# description           10
# release_year          10
# rental_duration       10
# rental_rate           10
# length                10
# replacement_cost      10
# rating                10
# special_features      10
# fulltext              10
# first_name            50
# last_name             50
# name                  10
# first_name.1         236
# last_name.1          236
# create_date          236
# active               236
# payment_id          8127
# amount              8127
# payment_date        8127
# address              232
# district             792
# city                 231
# country              231
# language               5
# dtype: int64

# %%
print("Jumlah duplikasi: ", rentaldvd3_df.duplicated().sum())
rentaldvd3_df.describe()
# Out:
# Jumlah duplikasi:  8
#        release_year  rental_duration   rental_rate        length  \
# count       88270.0     88270.000000  88270.000000  88270.000000
# mean         2006.0         4.920721      2.916793    115.111669
# std             0.0         1.380147      1.637133     40.498990
# min          2006.0         3.000000      0.990000     46.000000
# 25%          2006.0         4.000000      0.990000     80.000000
# 50%          2006.0         5.000000      2.990000    114.000000
# 75%          2006.0         6.000000      4.990000    150.000000
# max          2006.0         7.000000      4.990000    185.000000
#
#        replacement_cost        active    payment_id        amount
# count      88270.000000  88044.000000  80153.000000  80153.000000
# mean          20.185049      0.974252  24797.737714      4.177764
# std            6.088377      0.158385   4208.471510      2.351942
# min            9.990000      0.000000  17503.000000      0.000000
# 25%           14.990000      1.000000  21155.000000      2.990000
# 50%           20.990000      1.000000  24803.000000      3.990000
# 75%           24.990000      1.000000  28422.000000      4.990000
# max           29.990000      1.000000  32098.000000     11.990000

# %% [markdown]
# ## **Cleaning Data**

# %% [markdown]
# ### **Missing Values**

# %%
rentaldvd3_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", rentaldvd3_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
rentaldvd3_df[rentaldvd3_df["release_year"].isna()]
# Out:
#       title description  release_year  rental_duration  rental_rate  length  \
# 88270   NaN         NaN           NaN              NaN          NaN     NaN
# 88271   NaN         NaN           NaN              NaN          NaN     NaN
# 88272   NaN         NaN           NaN              NaN          NaN     NaN
# 88273   NaN         NaN           NaN              NaN          NaN     NaN
# 88274   NaN         NaN           NaN              NaN          NaN     NaN
# 88275   NaN         NaN           NaN              NaN          NaN     NaN
# 88276   NaN         NaN           NaN              NaN          NaN     NaN
# 88277   NaN         NaN           NaN              NaN          NaN     NaN
# 88278   NaN         NaN           NaN              NaN          NaN     NaN
# 88279   NaN         NaN           NaN              NaN          NaN     NaN
#
#        replacement_cost rating special_features fulltext  ... create_date  \
# 88270               NaN    NaN              NaN      NaN  ...         NaN
# 88271               NaN    NaN              NaN      NaN  ...         NaN
# 88272               NaN    NaN              NaN      NaN  ...         NaN
# 88273               NaN    NaN              NaN      NaN  ...         NaN
# 88274               NaN    NaN              NaN      NaN  ...         NaN
# 88275               NaN    NaN              NaN      NaN  ...         NaN
# 88276               NaN    NaN              NaN      NaN  ...         NaN
# 88277               NaN    NaN              NaN      NaN  ...         NaN
# 88278               NaN    NaN              NaN      NaN  ...         NaN
# 88279               NaN    NaN              NaN      NaN  ...         NaN
#
#       active payment_id amount payment_date               address  district  \
# 88270    NaN        NaN    NaN          NaN    28 MySQL Boulevard       QLD
# 88271    NaN        NaN    NaN          NaN  1411 Lillydale Drive       QLD
# 88272    NaN        NaN    NaN          NaN     47 MySakila Drive   Alberta
# 88273    NaN        NaN    NaN          NaN     23 Workhaven Lane   Alberta
# 88274    NaN        NaN    NaN          NaN                   NaN       NaN
# 88275    NaN        NaN    NaN          NaN                   NaN       NaN
# 88276    NaN        NaN    NaN          NaN                   NaN       NaN
# 88277    NaN        NaN    NaN          NaN                   NaN       NaN
# 88278    NaN        NaN    NaN          NaN                   NaN       NaN
# 88279    NaN        NaN    NaN          NaN                   NaN       NaN
#
#              city    country              language
# 88270   Woodridge  Australia                   NaN
# 88271   Woodridge  Australia                   NaN
# 88272  Lethbridge     Canada                   NaN
# 88273  Lethbridge     Canada                   NaN
# 88274      London     Canada                   NaN
# 88275         NaN        NaN  Italian
# 88276         NaN        NaN  French
# 88277         NaN        NaN  German
# 88278         NaN        NaN  Mandarin
# 88279         NaN        NaN  Japanese
#
# [10 rows x 25 columns]

# %%
rentaldvd3_df["release_year"].value_counts()
# Out:
# release_year
# 2006.0    88262
# Name: count, dtype: int64

# %%
rentaldvd3_df["release_year"].fillna(value=2006, inplace=True)
# Out:
# <ipython-input-63-83c271887580>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["release_year"].fillna(value=2006, inplace=True)

# %%
# Mengisi missing values dengan mean untuk kolom numerik
rentaldvd3_df["rental_duration"].fillna(rentaldvd3_df["rental_duration"].mean(), inplace=True)
rentaldvd3_df["rental_rate"].fillna(rentaldvd3_df["rental_rate"].mean(), inplace=True)
rentaldvd3_df["length"].fillna(rentaldvd3_df["length"].mean(), inplace=True)
rentaldvd3_df["replacement_cost"].fillna(rentaldvd3_df["replacement_cost"].mean(), inplace=True)
rentaldvd3_df["active"].fillna(rentaldvd3_df["active"].mean(), inplace=True)
rentaldvd3_df["amount"].fillna(rentaldvd3_df["amount"].mean(), inplace=True)
# Out:
# <ipython-input-64-bb573db8c5ae>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["rental_duration"].fillna(rentaldvd3_df["rental_duration"].mean(), inplace=True)
# <ipython-input-64-bb573db8c5ae>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["rental_rate"].fillna(rentaldvd3_df["rental_rate"].mean(), inplace=True)
# <ipython-input-64-bb573db8c5ae>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["length"].fillna(rentaldvd3_df["length"].mean(), inplace=True)
# <ipython-input-64-bb573db8c5ae>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["replacement_cost"].fillna(rentaldvd3_df["replacement_cost"].mean(), inplace=True)
# <ipython-input-64-bb573db8c5ae>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["active"].fillna(rentaldvd3_df["active"].mean(), inplace=True)
# <ipython-input-64-bb573db8c5ae>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df["amount"].fillna(rentaldvd3_df["amount"].mean(), inplace=True)

# %%
# Identifikasi nilai maksimum yang ada di kolom payment_id
max_id = rentaldvd3_df["payment_id"].max()

# Cari indeks dari baris dengan missing values
missing_indices = rentaldvd3_df[rentaldvd3_df["payment_id"].isna()].index

# Generate angka unik untuk mengisi missing values
new_ids = range(int(max_id) + 1, int(max_id) + 1 + len(missing_indices))

# Isi nilai missing values dengan angka unik
rentaldvd3_df.loc[missing_indices, "payment_id"] = new_ids

print("Missing values berhasil diisi dengan angka unik!")
# Out:
# Missing values berhasil diisi dengan angka unik!

# %%
# Hapus baris yang memiliki missing value sesuai kolom teks
rentaldvd3_df.dropna(subset=['title'], inplace=True)
rentaldvd3_df.dropna(subset=['first_name'], inplace=True)
rentaldvd3_df.dropna(subset=['first_name.1'], inplace=True)
rentaldvd3_df.dropna(subset=['address'], inplace=True)
rentaldvd3_df.dropna(subset=['district'], inplace=True)
rentaldvd3_df.dropna(subset=['city'], inplace=True)

# %%
# Tentukan tanggal pengganti
default_date = pd.to_datetime('2007-03-22 23:29:27.996577')

# Isi nilai missing dengan tanggal default
rentaldvd3_df['payment_date'].fillna(default_date, inplace=True)

print("Missing values pada kolom 'payment_date' berhasil diisi dengan tanggal default!")
# Out:
# Missing values pada kolom 'payment_date' berhasil diisi dengan tanggal default!
# <ipython-input-67-0aabcb4bffd3>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rentaldvd3_df['payment_date'].fillna(default_date, inplace=True)

# %%
missing_values = rentaldvd3_df.isna().sum()
missing_percentage = (rentaldvd3_df.isna().sum() / len(rentaldvd3_df)) * 100

print(missing_values)
print(missing_percentage)
# Out:
# title               0
# description         0
# release_year        0
# rental_duration     0
# rental_rate         0
# length              0
# replacement_cost    0
# rating              0
# special_features    0
# fulltext            0
# first_name          0
# last_name           0
# name                0
# first_name.1        0
# last_name.1         0
# create_date         0
# active              0
# payment_id          0
# amount              0
# payment_date        0
# address             0
# district            0
# city                0
# country             0
# language            0
# dtype: int64
# title               0.0
# description         0.0
# release_year        0.0
# rental_duration     0.0
# rental_rate         0.0
# length              0.0
# replacement_cost    0.0
# rating              0.0
# special_features    0.0
# fulltext            0.0
# first_name          0.0
# last_name           0.0
# name                0.0
# first_name.1        0.0
# last_name.1         0.0
# create_date         0.0
# active              0.0
# payment_id          0.0
# amount              0.0
# payment_date        0.0
# address             0.0
# district            0.0
# city                0.0
# country             0.0
# language            0.0
# dtype: float64

# %%
# Menyimpan DataFrame sebagai file CSV
rentaldvd3_df.to_csv("rentaldvd3_data.csv", index=False)  # index=False untuk tidak menyimpan index

# Membuat link untuk mengunduh file
from google.colab import files
files.download("rentaldvd3_data.csv")

# %% [markdown]
# ## **Path File Baru Setelah Data Cleaning**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path ke file clean
rentaldvd3_df = pd.read_csv('/content/drive/MyDrive/MMB/rentaldvd3_data.csv')
rentaldvd3_df.head()
# Out:
#               title                                        description  \
# 0  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 2  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 3  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 4  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
#
#    release_year  rental_duration  rental_rate  length  replacement_cost  \
# 0        2006.0              6.0         0.99    86.0             20.99
# 1        2006.0              6.0         0.99    86.0             20.99
# 2        2006.0              6.0         0.99    86.0             20.99
# 3        2006.0              6.0         0.99    86.0             20.99
# 4        2006.0              6.0         0.99    86.0             20.99
#
#   rating                        special_features  \
# 0     PG  {"Deleted Scenes","Behind the Scenes"}
# 1     PG  {"Deleted Scenes","Behind the Scenes"}
# 2     PG  {"Deleted Scenes","Behind the Scenes"}
# 3     PG  {"Deleted Scenes","Behind the Scenes"}
# 4     PG  {"Deleted Scenes","Behind the Scenes"}
#
#                                             fulltext  ... create_date active  \
# 0  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 1  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 2  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 3  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
# 4  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...  14/02/2006    1.0
#
#   payment_id amount                payment_date                       address  \
# 0    19665.0   3.99  2007-03-21 19:56:09.996577           600 Bradford Street
# 1    21895.0   3.99  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor
# 2    27023.0   0.99  2007-04-08 17:31:41.996577         287 Cuautla Boulevard
# 3    19665.0   3.99  2007-03-21 19:56:09.996577           600 Bradford Street
# 4    21895.0   3.99  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor
#
#            district    city  country              language
# 0  East Azerbaidzan  Tabriz     Iran  English
# 1             Sivas   Sivas   Turkey  English
# 2        Chuquisaca   Sucre  Bolivia  English
# 3  East Azerbaidzan  Tabriz     Iran  English
# 4             Sivas   Sivas   Turkey  English
#
# [5 rows x 25 columns]

# %%
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        data = pd.read_csv(file_path, delimiter=';')
        print(f"Loaded {filename} with shape {data.shape}")
# Out:
# Loaded dvdrental1_db.csv with shape (80115, 10)
# Loaded dvdrental3_db.csv with shape (88280, 25)
# Loaded rentaldvd3_data.csv with shape (87436, 1)

# %%
rentaldvd3_df.info()
rentaldvd3_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87436 entries, 0 to 87435
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             87436 non-null  object
#  1   description       87436 non-null  object
#  2   release_year      87436 non-null  float64
#  3   rental_duration   87436 non-null  float64
#  4   rental_rate       87436 non-null  float64
#  5   length            87436 non-null  float64
#  6   replacement_cost  87436 non-null  float64
#  7   rating            87436 non-null  object
#  8   special_features  87436 non-null  object
#  9   fulltext          87436 non-null  object
#  10  first_name        87436 non-null  object
#  11  last_name         87436 non-null  object
#  12  name              87436 non-null  object
#  13  first_name.1      87436 non-null  object
#  14  last_name.1       87436 non-null  object
#  15  create_date       87436 non-null  object
#  16  active            87436 non-null  float64
#  17  payment_id        87436 non-null  float64
#  18  amount            87436 non-null  float64
#  19  payment_date      87436 non-null  object
#  20  address           87436 non-null  object
#  21  district          87436 non-null  object
#  22  city              87436 non-null  object
#  23  country           87436 non-null  object
#  24  language          87436 non-null  object
# dtypes: float64(8), object(17)
# memory usage: 16.7+ MB
# title               0
# description         0
# release_year        0
# rental_duration     0
# rental_rate         0
# length              0
# replacement_cost    0
# rating              0
# special_features    0
# fulltext            0
# first_name          0
# last_name           0
# name                0
# first_name.1        0
# last_name.1         0
# create_date         0
# active              0
# payment_id          0
# amount              0
# payment_date        0
# address             0
# district            0
# city                0
# country             0
# language            0
# dtype: int64

# %%
print("Jumlah duplikasi: ", rentaldvd3_df.duplicated().sum())
rentaldvd3_df.describe()
# Out:
# Jumlah duplikasi:  0
#        release_year  rental_duration   rental_rate        length  \
# count       87436.0     87436.000000  87436.000000  87436.000000
# mean         2006.0         4.917471      2.916804    115.108983
# std             0.0         1.379524      1.637230     40.510271
# min          2006.0         3.000000      0.990000     46.000000
# 25%          2006.0         4.000000      0.990000     80.000000
# 50%          2006.0         5.000000      2.990000    114.000000
# 75%          2006.0         6.000000      4.990000    150.000000
# max          2006.0         7.000000      4.990000    185.000000
#
#        replacement_cost        active    payment_id        amount
# count      87436.000000  87436.000000  87436.000000  87436.000000
# mean          20.188214      0.974084  25812.956768      4.178079
# std            6.090584      0.158886   5190.196446      2.244964
# min            9.990000      0.000000  17503.000000      0.000000
# 25%           14.990000      1.000000  21514.000000      2.990000
# 50%           20.990000      1.000000  25514.000000      4.177764
# 75%           24.990000      1.000000  29523.000000      4.990000
# max           29.990000      1.000000  39991.000000     11.990000

# %% [markdown]
# ## ***Exploratory Data Analysis (EDA)***

# %% [markdown]
# ### **Jumlah Perental di Dunia**

# %%
byCountry = (
    rentaldvd3_df.groupby(by="country")["title"]
    .size()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(byCountry)
# Out:
# country
# India             8637
# China             7724
# United States     5452
# Japan             4565
# Mexico            4493
#                   ...
# Tonga              118
# French Guiana      117
# Lithuania          114
# American Samoa     111
# Afghanistan        109
# Name: title, Length: 105, dtype: int64

# %%
# Konversi hasil groupby menjadi DataFrame
byCountry_df = byCountry.reset_index()
byCountry_df.columns = ['country', 'count']  # Memberi nama kolom

# Visualisasi dengan seaborn
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(x='country', y='count', data=byCountry_df, palette='viridis')

plt.title("Jumlah Rental DVD Berdasarkan Negara", fontsize=16)
plt.xlabel("Negara", fontsize=12)
plt.ylabel("Jumlah DVD yang Dirental", fontsize=12)
plt.xticks(rotation=45)  # Memiringkan label x agar mudah dibaca

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-102-022009747fe5>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='country', y='count', data=byCountry_df, palette='viridis')

# %%
# Menampilkan 10 judul film terbanyak
top_rentals_world = byCountry_df.head(10)
print(top_rentals_world)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='country', x='count', data=top_rentals_world, palette='viridis')

plt.title("Top 10 Perental DVD di Dunia Berdasarkan Negara", fontsize=16)
plt.ylabel("Nama Negara", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#               country  count
# 0               India   8637
# 1               China   7724
# 2       United States   5452
# 3               Japan   4565
# 4              Mexico   4493
# 5              Brazil   4042
# 6  Russian Federation   3895
# 7         Philippines   3160
# 8              Turkey   2094
# 9           Indonesia   2014
# <ipython-input-104-3c11d6453845>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='country', x='count', data=top_rentals_world, palette='viridis')

# %% [markdown]
# ### **Jumlah Perental di Indonesia**

# %%
# Filter hanya untuk country "Indonesia"
indonesia_data = rentaldvd3_df[rentaldvd3_df["country"] == "Indonesia"]

# Groupby berdasarkan judul film untuk menghitung jumlah penyewa
rental_count_per_title = (
    indonesia_data.groupby(by="title")
    .size()  # Menghitung jumlah penyewaan per judul
    .sort_values(ascending=False)  # Mengurutkan dari terbanyak ke sedikit
)

# Total jumlah semua penyewa di Indonesia
total_rentals = rental_per_title.sum()

# Menampilkan hasil
print(f"Total penyewa di Indonesia berdasarkan judul film: \n{rental_count_per_title}")
print(f"\nJumlah total penyewa di Indonesia: {total_rentals}")
# Out:
# Total penyewa di Indonesia berdasarkan judul film:
# title
# Crazy Home           26
# Necklace Outbreak    24
# Minds Truman         18
# Crooked Frogmen      18
# Metropolis Coma      18
#                      ..
# Baked Cleopatra       1
# Forever Candidate     1
# Maltese Hope          1
# Dwarfs Alter          1
# Yentl Idaho           1
# Length: 306, dtype: int64
#
# Jumlah total penyewa di Indonesia: 2014.0

# %%
# Konversi hasil menjadi DataFrame
rental_count_per_title_df = rental_count_per_title.reset_index()
rental_count_per_title_df.columns = ['title', 'count']

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=rental_count_per_title_df, palette='viridis')

plt.title("Jumlah Rental DVD di Indonesia Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-95-9d8e15f78208>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=rental_count_per_title_df, palette='viridis')

# %%
# Menampilkan 10 judul film terbanyak
top_rentals = rental_count_per_title_df.head(10)
print(top_rentals)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

plt.title("Top 10 Jumlah Rental DVD di Indonesia Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#                    title  count
# 0             Crazy Home     26
# 1      Necklace Outbreak     24
# 2           Minds Truman     18
# 3        Crooked Frogmen     18
# 4        Metropolis Coma     18
# 5            Born Spinal     18
# 6  Flamingos Connecticut     18
# 7             Sea Virgin     16
# 8        Suspects Quills     16
# 9           Horn Working     16
# <ipython-input-105-47d51c048d88>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

# %% [markdown]
# ### **Jumlah Perental di India**

# %%
# Filter hanya untuk country "India"
india_data = rentaldvd3_df[rentaldvd3_df["country"] == "India"]

# Groupby berdasarkan judul film untuk menghitung jumlah penyewa
rental_count_india = (
    india_data.groupby(by="title")
    .size()  # Menghitung jumlah penyewaan per judul
    .sort_values(ascending=False)  # Mengurutkan dari terbanyak ke sedikit
)

# Total jumlah semua penyewa di India
total_india = rental_count_india.sum()

# Menampilkan hasil
print(f"Total penyewa di India berdasarkan judul film: \n{rental_count_india}")
print(f"\nJumlah total penyewa di India: {total_india}")
# Out:
# Total penyewa di India berdasarkan judul film:
# title
# Fiction Christmas      56
# Mask Peach             55
# Wife Turn              54
# Splendor Patton        50
# Hellfighters Sierra    48
#                        ..
# Moon Bunch              1
# Minority Kiss           1
# Maltese Hope            1
# Yentl Idaho             1
# Lolita World            1
# Length: 746, dtype: int64
#
# Jumlah total penyewa di India: 8640

# %%
# Konversi hasil menjadi DataFrame
rental_count_india_df = rental_count_per_title.reset_index()
rental_count_india_df.columns = ['title', 'count']

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=rental_count_india_df, palette='viridis')

plt.title("Jumlah Rental DVD di India Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-15-23ae24dab8ba>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=rental_count_india_df, palette='viridis')

# %%
# Menampilkan 10 judul film terbanyak
top_rentals = rental_count_india_df.head(10)
print(top_rentals)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

plt.title("Top 10 Jumlah Rental DVD di India Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#                  title  count
# 0    Fiction Christmas     56
# 1           Mask Peach     55
# 2            Wife Turn     54
# 3      Splendor Patton     50
# 4  Hellfighters Sierra     48
# 5     Fantasy Troopers     45
# 6         Family Sweet     45
# 7     Instinct Airport     44
# 8      Idols Snatchers     40
# 9        Jerk Paycheck     40
# <ipython-input-17-331497b5f133>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

# %% [markdown]
# ### **Jumlah Perental di China**

# %%
# Filter hanya untuk country "China"
china_data = rentaldvd3_df[rentaldvd3_df["country"] == "China"]

# Groupby berdasarkan judul film untuk menghitung jumlah penyewa
rental_count_china = (
    china_data.groupby(by="title")
    .size()  # Menghitung jumlah penyewaan per judul
    .sort_values(ascending=False)  # Mengurutkan dari terbanyak ke sedikit
)

# Total jumlah semua penyewa di China
total_china = rental_count_china.sum()

# Menampilkan hasil
print(f"Total penyewa di China berdasarkan judul film: \n{rental_count_china}")
print(f"\nJumlah total penyewa di China: {total_china}")
# Out:
# Total penyewa di China berdasarkan judul film:
# title
# Oz Liaisons         55
# Wedding Apollo      50
# House Dynamite      45
# Balloon Homeward    42
# Cleopatra Devil     42
#                     ..
# Drumline Cyclone     1
# Pirates Roxanne      1
# Miracle Virtual      1
# Ghostbusters Elf     1
# Dwarfs Alter         1
# Length: 721, dtype: int64
#
# Jumlah total penyewa di China: 7729

# %%
# Konversi hasil menjadi DataFrame
rental_count_china_df = rental_count_china.reset_index()
rental_count_china_df.columns = ['title', 'count']

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=rental_count_china_df, palette='viridis')

plt.title("Jumlah Rental DVD di China Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-25-d22ead3b3bc9>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=rental_count_china_df, palette='viridis')

# %%
# Menampilkan 10 judul film terbanyak
top_rentals = rental_count_china_df.head(10)
print(top_rentals)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

plt.title("Top 10 Jumlah Rental DVD di China Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#               title  count
# 0       Oz Liaisons     55
# 1    Wedding Apollo     50
# 2    House Dynamite     45
# 3  Balloon Homeward     42
# 4   Cleopatra Devil     42
# 5        Story Side     40
# 6   Storm Happiness     40
# 7      Hobbit Alien     40
# 8     Kick Savannah     36
# 9         West Lion     36
# <ipython-input-26-dac7d335cea5>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

# %% [markdown]
# ### **Jumlah Perental di United States**

# %%
# Filter hanya untuk country "United States"
us_data = rentaldvd3_df[rentaldvd3_df["country"] == "United States"]

# Groupby berdasarkan judul film untuk menghitung jumlah penyewa
rental_count_us = (
    us_data.groupby(by="title")
    .size()  # Menghitung jumlah penyewaan per judul
    .sort_values(ascending=False)  # Mengurutkan dari terbanyak ke sedikit
)

# Total jumlah semua penyewa di India
total_us = rental_count_us.sum()

# Menampilkan hasil
print(f"Total penyewa di United States berdasarkan judul film: \n{rental_count_us}")
print(f"\nJumlah total penyewa di United States: {total_us}")
# Out:
# Total penyewa di United States berdasarkan judul film:
# title
# Sleuth Orient             42
# Dracula Crystal           39
# Submarine Bed             33
# Telemark Heartbreakers    33
# Spy Mile                  32
#                           ..
# Drumline Cyclone           1
# Maltese Hope               1
# Musketeers Wait            1
# Baked Cleopatra            1
# Stone Fire                 1
# Length: 598, dtype: int64
#
# Jumlah total penyewa di United States: 5455

# %%
# Konversi hasil menjadi DataFrame
rental_count_us_df = rental_count_us.reset_index()
rental_count_us_df.columns = ['title', 'count']

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=rental_count_us_df, palette='viridis')

plt.title("Jumlah Rental DVD di United States Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-30-b63359d552bc>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=rental_count_us_df, palette='viridis')

# %%
# Menampilkan 10 judul film terbanyak
top_rentals = rental_count_us_df.head(10)
print(top_rentals)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

plt.title("Top 10 Jumlah Rental DVD di United States Berdasarkan Judul Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah DVD yang Dirental", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#                     title  count
# 0           Sleuth Orient     42
# 1         Dracula Crystal     39
# 2           Submarine Bed     33
# 3  Telemark Heartbreakers     33
# 4                Spy Mile     32
# 5         Scorpion Apollo     32
# 6        Cupboard Sinners     32
# 7          Wedding Apollo     30
# 8           Jungle Closer     30
# 9            Pulp Beverly     28
# <ipython-input-31-0e36f0ca41ea>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='count', data=top_rentals, palette='viridis')

# %% [markdown]
# ### **Genre Paling Diminati**

# %%
byGenre = (
    rentaldvd3_df.groupby(by="name")["country"]
    .size()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(byGenre)
# Out:
# name
# Sports         6953
# Animation      6610
# Action         6327
# Documentary    6220
# Drama          5954
# Sci-Fi         5750
# Family         5624
# Foreign        5590
# Children       5518
# New            5234
# Classics       5105
# Horror         4943
# Travel         4708
# Comedy         4667
# Games          4564
# Music          4503
# Name: country, dtype: int64

# %%
byGenre = (
    rentaldvd3_df.groupby(by="name")["country"]
    .size()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(byGenre)
# Out:
# name
# 14    6918
# 1     6582
# 0     6270
# 5     6146
# 6     5858
# 13    5686
# 7     5583
# 8     5532
# 2     5467
# 12    5193
# 3     5063
# 10    4898
# 4     4637
# 15    4632
# 9     4510
# 11    4461
# Name: country, dtype: int64

# %%
# Konversi hasil groupby menjadi DataFrame
byGenre_df = byGenre.reset_index()
byGenre_df.columns = ['genre', 'count']  # Memberi nama kolom

# Visualisasi dengan seaborn
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(x='genre', y='count', data=byGenre_df, palette='viridis')

plt.title("Genre Paling Diminati", fontsize=16)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Jumlah Peminat", fontsize=12)
plt.xticks(rotation=45)  # Memiringkan label x agar mudah dibaca

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-37-2ef711cf9f9d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='genre', y='count', data=byGenre_df, palette='viridis')

# %%
# Menampilkan 10 Genre Paling Diminati
top_genre = byGenre_df.head(10)
print(top_genre)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='genre', x='count', data=top_genre, palette='viridis')

plt.title("Top 10 Genre Paling Diminati", fontsize=16)
plt.ylabel("Nama Genre", fontsize=12)
plt.xlabel("Jumlah Peminat", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#          genre  count
# 0       Sports   6953
# 1    Animation   6610
# 2       Action   6327
# 3  Documentary   6220
# 4        Drama   5954
# 5       Sci-Fi   5750
# 6       Family   5624
# 7      Foreign   5590
# 8     Children   5518
# 9          New   5234
# <ipython-input-41-c1cf2456a7cb>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='genre', x='count', data=top_genre, palette='viridis')

# %% [markdown]
# ### **Penghasilan Rata-Rata setiap Film yang Dirental**

# %%
byMean = (
    rentaldvd3_df.groupby(by="title")["amount"]
    .mean()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(byMean)
# Out:
# title
# Backlash Undefeated    8.802500
# Hustler Party          8.671818
# Tycoon Gathering       8.656667
# Telegraph Voyage       8.630000
# Caribbean Liberty      8.365000
#                          ...
# Treasure Command            NaN
# Villain Desperate           NaN
# Volume House                NaN
# Wake Jaws                   NaN
# Walls Artist                NaN
# Name: amount, Length: 1000, dtype: float64

# %%
# Konversi hasil groupby menjadi DataFrame
byMean_df = byMean.reset_index()
byMean_df.columns = ['judul', 'mean']  # Memberi nama kolom

# Visualisasi dengan seaborn
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(x='judul', y='mean', data=byMean_df, palette='viridis')

plt.title("Penghasilan Rata-Rata setiap Film yang Dirental", fontsize=16)
plt.xlabel("Judul Film", fontsize=12)
plt.ylabel("Rata-Rata Penghasilan", fontsize=12)
plt.xticks(rotation=45)  # Memiringkan label x agar mudah dibaca

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-40-d5c6447a270d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='judul', y='mean', data=byMean_df, palette='viridis')

# %%
# Menampilkan 10 Penghasilan Teratas
top_mean = byMean_df.head(10)
print(top_genre)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='judul', x='mean', data=top_genre, palette='viridis')

plt.title("Penghasilan Rata-Rata setiap Film yang Dirental", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Rata-Rata Penghasilan ($)", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#                  judul      mean
# 0  Backlash Undefeated  8.802500
# 1        Hustler Party  8.671818
# 2     Tycoon Gathering  8.656667
# 3     Telegraph Voyage  8.630000
# 4    Caribbean Liberty  8.365000
# 5        Paths Control  8.190000
# 6          Mine Titans  8.166471
# 7         Park Citizen  8.156667
# 8     Virtual Spoilers  8.143846
# 9     Behavior Runaway  7.990000
# <ipython-input-44-8514d2ee72b2>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='judul', x='mean', data=top_genre, palette='viridis')

# %% [markdown]
# ### **Jumlah Penghasilan setiap Film yang Dirental**

# %%
bySum = (
    rentaldvd3_df.groupby(by="title")["amount"]
    .size()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(bySum)
# Out:
# title
# Juggler Hardly            288
# Titanic Boondock          276
# Telemark Heartbreakers    275
# Dracula Crystal           273
# Oz Liaisons               264
#                          ...
# Butch Panther               3
# Villain Desperate           2
# Crossing Divorce            2
# Frankenstein Stranger       2
# Psycho Shrunk               1
# Name: amount, Length: 1000, dtype: int64

# %%
# Konversi hasil groupby menjadi DataFrame
bySum_df = bySum.reset_index()
bySum_df.columns = ['judul', 'jumlah']  # Memberi nama kolom

# Visualisasi dengan seaborn
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(x='judul', y='jumlah', data=bySum_df, palette='viridis')

plt.title("Jumlah Penghasilan setiap Film yang Dirental", fontsize=16)
plt.xlabel("Judul Film", fontsize=12)
plt.ylabel("Jumlah Penghasilan", fontsize=12)
plt.xticks(rotation=45)  # Memiringkan label x agar mudah dibaca

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# <ipython-input-46-b76d1270c6c3>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='judul', y='jumlah', data=bySum_df, palette='viridis')

# %%
# Menampilkan 10 Jumlah Penghasilan Teratas
top_sum = bySum_df.head(10)
print(top_sum)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='judul', x='jumlah', data=top_sum, palette='viridis')

plt.title("Jumlah Penghasilan setiap Film yang Dirental", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah Penghasilan ($)", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
#                     judul  jumlah
# 0          Juggler Hardly     288
# 1        Titanic Boondock     276
# 2  Telemark Heartbreakers     275
# 3         Dracula Crystal     273
# 4             Oz Liaisons     264
# 5            Family Sweet     261
# 6          Saturday Lambs     252
# 7            Hobbit Alien     248
# 8       Goodfellas Salute     248
# 9         Idols Snatchers     240
# <ipython-input-48-efeae705148f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='judul', x='jumlah', data=top_sum, palette='viridis')

# %% [markdown]
# ### **Durasi Rental Setiap Film**

# %%
byDuration = (
    rentaldvd3_df.groupby(by="title")["rental_duration"]
    .size()  # Menghitung jumlah data di setiap grup
    .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
)

print(byDuration)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fad73d343266> in <cell line: 2>()
#       1 byDuration = (
# ----> 2     rentaldvd3_df.groupby(by="title")["rental_duration"]
#       3     .size()  # Menghitung jumlah data di setiap grup
#       4     .sort_values(ascending=False)  # Mengurutkan dari besar ke kecil
#       5 )
#
# NameError: name 'rentaldvd3_df' is not defined

# %%
# Konversi hasil groupby menjadi DataFrame
byDuration_df = byDuration.reset_index()
byDuration_df.columns = ['judul', 'durasi']  # Memberi nama kolom

# Visualisasi dengan seaborn
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(x='judul', y='durasi', data=byDuration_df, palette='viridis')

plt.title("Durasi Rental Setiap Film", fontsize=16)
plt.xlabel("Judul Film", fontsize=12)
plt.ylabel("Jumlah Durasi (Hari)", fontsize=12)
plt.xticks(rotation=45)  # Memiringkan label x agar mudah dibaca

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c8f81621da6d> in <cell line: 2>()
#       1 # Konversi hasil groupby menjadi DataFrame
# ----> 2 byDuration_df = byDuration.reset_index()
#       3 byDuration_df.columns = ['judul', 'durasi']  # Memberi nama kolom
#       4
#       5 # Visualisasi dengan seaborn
#
# NameError: name 'byDuration' is not defined

# %%
# Menampilkan 10 Jumlah Waktu Rental Terbanyak
top_durasi = byDuration_df.head(10)
print(top_durasi)

# Visualisasi dengan seaborn (bar chart horizontal)
plt.figure(figsize=(12, 6))  # Ukuran grafik
sns.barplot(y='judul', x='durasi', data=top_durasi, palette='viridis')

plt.title("Durasi Rental Setiap Film", fontsize=16)
plt.ylabel("Judul Film", fontsize=12)
plt.xlabel("Jumlah Durasi (Hari)", fontsize=12)

plt.tight_layout()  # Mengatur tata letak agar tidak tumpang tindih
plt.show()

# %% [markdown]
# # **Customer Segmentation**

# %%
# Hanya mengambil fitur "Annual Income" dan "Spending Score"
clustering = rentaldvd3_df.iloc[:, 3:5] # 3:5 artinya adalah mengambil kolom index 3 sampai 4 (atau 5-1)
clustering.head()
# Out:
#    rental_duration  rental_rate
# 0              6.0         0.99
# 1              6.0         0.99
# 2              6.0         0.99
# 3              6.0         0.99
# 4              6.0         0.99

# %%
wcss = [] # wcss -> Within Cluster Sum of Squares

for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, random_state = 14)
    kmeans.fit(clustering)
    wcss.append(kmeans.inertia_)

# Visualisasi Metode Elbow
plt.plot(range(1, 15), wcss)
plt.title("The Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# **K yang paling tepat kemungkinan 4 atau 5**
#
# ---

# %%
# Pakai cluster = 6
kmeans = KMeans(n_clusters = 6, random_state = 14)
kmeans.fit(clustering)
# Out:
# KMeans(n_clusters=6, random_state=14)

# %%
kmeans.labels_
# Out:
# array([5, 5, 5, ..., 4, 4, 4], dtype=int32)

# %%
hasil_kmeans = clustering.copy()
hasil_kmeans["cluster"] = kmeans.labels_
hasil_kmeans.head()
# Out:
#    rental_duration  rental_rate  cluster
# 0              6.0         0.99        5
# 1              6.0         0.99        5
# 2              6.0         0.99        5
# 3              6.0         0.99        5
# 4              6.0         0.99        5

# %%
# Nilai untuk sumbu X dan Y
cluster_x = hasil_kmeans["cluster"].value_counts().index
cluster_y = hasil_kmeans["cluster"].value_counts().values

# Visualisasi
sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
plt.title("Frekuensi Data pada Masing-Masing Cluster (KMeans)")
plt.xlabel("Cluster")
plt.ylabel("Frekuensi")
# Out:
# <ipython-input-93-9773dc406189>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
# Text(0, 0.5, 'Frekuensi')

# %%
# Nilai fitur/variabel dari masing-masing cluster
ann_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 0]
spend_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 1]
ann_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 0]
spend_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 1]
ann_kmeans2 = hasil_kmeans[hasil_kmeans["cluster"] == 2].iloc[:, 0]
spend_kmeans2 = hasil_kmeans[hasil_kmeans["cluster"] == 2].iloc[:, 1]
ann_kmeans3 = hasil_kmeans[hasil_kmeans["cluster"] == 3].iloc[:, 0]
spend_kmeans3 = hasil_kmeans[hasil_kmeans["cluster"] == 3].iloc[:, 1]
ann_kmeans4 = hasil_kmeans[hasil_kmeans["cluster"] == 4].iloc[:, 0]
spend_kmeans4 = hasil_kmeans[hasil_kmeans["cluster"] == 4].iloc[:, 1]

# Pusat dari cluster (centroid)
centroid_cluster = kmeans.cluster_centers_
centroid_cluster
# Out:
# array([[3.88674382, 0.99      ],
#        [5.88840091, 4.99      ],
#        [3.52690705, 2.99      ],
#        [5.97710312, 2.99      ],
#        [3.51854846, 4.99      ],
#        [6.38923711, 0.99      ]])

# %%
# VISUALISASI HASIL CLUSTERING
plt.scatter(ann_kmeans0, spend_kmeans0, s = 80, c = "blue", label = "Cluster 1")
plt.scatter(ann_kmeans1, spend_kmeans1, s = 80, c = "orange", label = "Cluster 2")
plt.scatter(ann_kmeans2, spend_kmeans2, s = 80, c = "green", label = "Cluster 3")
plt.scatter(ann_kmeans3, spend_kmeans3, s = 80, c = "red", label = "Cluster 4")
plt.scatter(ann_kmeans4, spend_kmeans4, s = 80, c = "magenta", label = "Cluster 5")

# Centroid
plt.scatter(centroid_cluster[:, 0], centroid_cluster[:, 1], s = 160, c = "black", label = "Centroids")
plt.title("Clusters of Customers")
plt.xlabel("Rental Duration")
plt.ylabel("Rental Rate")
plt.legend()
plt.show()

# %%
# Memasukkan kembali "payment_id"-nya
hasil_kmeans["CustomerID"] = rentaldvd3_df["payment_id"]
hasil_kmeans.head()
# Out:
#    rental_duration  rental_rate  cluster  CustomerID
# 0              6.0         0.99        5     19665.0
# 1              6.0         0.99        5     21895.0
# 2              6.0         0.99        5     27023.0
# 3              6.0         0.99        5     19665.0
# 4              6.0         0.99        5     21895.0

# %%
# Menyimpan Hasil Akhir sebagai file CSV
hasil_kmeans.to_csv("hasil_rentaldvd.csv", index=False)  # index=False untuk tidak menyimpan index

# Membuat link untuk mengunduh file
from google.colab import files
files.download("hasil_rentaldvd.csv")

'''
Silahkan unduh jika diperlukan.
'''

# %% [markdown]
# ### **Interpretasi Hasil Clustering**

# %% [markdown]
# **Dengan melihat hasil scatter plot, kita dapat mengetahui perbedaan perilaku dari customer pada masing-masing cluster sebagai berikut:**
#
# **Cluster 1 -> Rental Duration RENDAH, Rental Rate RENDAH**
#
# **Cluster 2 -> Rental Duration TINGGI, Rental Rate TINGGI**
#
# **Cluster 3 -> Rental Duration RENDAH, Rental Rate SEDANG**
#
# **Cluster 4 -> Rental Duration TINGGI, Rental Rate SEDANG**
#
# **Cluster 5 -> Rental Duration RENDAH, Rental Rate TINGGI**

# %% [markdown]
# # **Customer Segmentation pt. 2**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

# Tampilkan data awal
print("Data Awal:")
print(rentaldvd3_df.head())

# Konversi kolom string menjadi integer (menggunakan LabelEncoder)
label_encoder = LabelEncoder()
rentaldvd3_df['name_encoded'] = label_encoder.fit_transform(rentaldvd3_df['name'])

# Tampilkan data setelah encoding
print("\nData Setelah Encoding:")
print(rentaldvd3_df[['name', 'name_encoded']].head())
# Out:
# Data Awal:
#               title                                        description  \
# 0  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 2  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 3  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 4  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
#
#    release_year  rental_duration  rental_rate  length  replacement_cost  \
# 0        2006.0              6.0         0.99    86.0             20.99
# 1        2006.0              6.0         0.99    86.0             20.99
# 2        2006.0              6.0         0.99    86.0             20.99
# 3        2006.0              6.0         0.99    86.0             20.99
# 4        2006.0              6.0         0.99    86.0             20.99
#
#   rating                        special_features  \
# 0     PG  {"Deleted Scenes","Behind the Scenes"}
# 1     PG  {"Deleted Scenes","Behind the Scenes"}
# 2     PG  {"Deleted Scenes","Behind the Scenes"}
# 3     PG  {"Deleted Scenes","Behind the Scenes"}
# 4     PG  {"Deleted Scenes","Behind the Scenes"}
#
#                                             fulltext  ... payment_id amount  \
# 0  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...    19665.0   3.99
# 1  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...    21895.0   3.99
# 2  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...    27023.0   0.99
# 3  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...    19665.0   3.99
# 4  'academi':1 'battl':15 'canadian':20 'dinosaur...  ...    21895.0   3.99
#
#                  payment_date                       address          district  \
# 0  2007-03-21 19:56:09.996577           600 Bradford Street  East Azerbaidzan
# 1  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor             Sivas
# 2  2007-04-08 17:31:41.996577         287 Cuautla Boulevard        Chuquisaca
# 3  2007-03-21 19:56:09.996577           600 Bradford Street  East Azerbaidzan
# 4  2007-03-02 18:41:36.996577  680 A Corua (La Corua) Manor             Sivas
#
#      city  country              language  name_encoded  name_pca
# 0  Tabriz     Iran  English                          5 -2.338796
# 1   Sivas   Turkey  English                          5 -2.338796
# 2   Sucre  Bolivia  English                          5 -2.338796
# 3  Tabriz     Iran  English                          5 -2.338796
# 4   Sivas   Turkey  English                          5 -2.338796
#
# [5 rows x 27 columns]
#
# Data Setelah Encoding:
#   name  name_encoded
# 0    5             5
# 1    5             5
# 2    5             5
# 3    5             5
# 4    5             5

# %%
# Contoh DataFrame
data = {'name': ['Sports', 'Animation', 'Action', 'Documentary', 'Drama', 'Sci-Fi', 'Family', 'Foreign', 'Children', 'New', 'Classics', 'Horror', 'Travel', 'Comedy', 'Games', 'Music']}

# Fit dan transformasi kolom 'genre'
rentaldvd3_df['genre_encoded'] = label_encoder.fit_transform(rentaldvd3_df['name'])

# %%
# Ubah kolom index 12 pada DataFrame asli
rentaldvd3_df.iloc[:, 12] = label_encoder.fit_transform(rentaldvd3_df.iloc[:, 12])

# %%
# Kembalikan kolom 'genre_encoded' ke bentuk aslinya
rentaldvd3_df['genre_decoded'] = label_encoder.inverse_transform(rentaldvd3_df['genre_encoded'])

# Tampilkan hasil
print(rentaldvd3_df)

# %%
from sklearn.preprocessing import LabelEncoder

# Buat salinan data untuk pengolahan
clustering = rentaldvd3_df.iloc[:, [12, 18]].copy()

# Inisialisasi LabelEncoder
label_encoder = LabelEncoder()

# Ubah kolom dengan indeks 12 menjadi integer
# Gunakan iloc untuk mengakses kolom berdasarkan indeks
clustering.iloc[:, 1] = label_encoder.fit_transform(clustering.iloc[:, 1])

# Tampilkan hasil
print(clustering.head())
# Out:
#   name  amount
# 0    5     6.0
# 1    5     6.0
# 2    5     1.0
# 3    5     6.0
# 4    5     6.0

# %%
wcss = [] # wcss -> Within Cluster Sum of Squares

for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, random_state = 14)
    kmeans.fit(clustering)
    wcss.append(kmeans.inertia_)

# Visualisasi Metode Elbow
plt.plot(range(1, 15), wcss)
plt.title("The Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# ## **Cluster = 2**

# %%
# Pakai cluster = 2
kmeans = KMeans(n_clusters = 2, random_state = 14)
kmeans.fit(clustering)
# Out:
# KMeans(n_clusters=2, random_state=14)

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
hasil_kmeans = clustering.copy()
hasil_kmeans["cluster"] = kmeans.labels_
hasil_kmeans.head()
# Out:
#   name  amount  cluster
# 0    5     6.0        0
# 1    5     6.0        0
# 2    5     1.0        0
# 3    5     6.0        0
# 4    5     6.0        0

# %%
# Nilai untuk sumbu X dan Y
cluster_x = hasil_kmeans["cluster"].value_counts().index
cluster_y = hasil_kmeans["cluster"].value_counts().values

# Visualisasi
sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
plt.title("Frekuensi Data pada Masing-Masing Cluster (KMeans)")
plt.xlabel("Cluster")
plt.ylabel("Frekuensi")
# Out:
# <ipython-input-50-9773dc406189>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
# Text(0, 0.5, 'Frekuensi')

# %%
# Nilai fitur/variabel dari masing-masing cluster
ann_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 0]
spend_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 1]
ann_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 0]
spend_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 1]

# Pusat dari cluster (centroid)
centroid_cluster = kmeans.cluster_centers_
centroid_cluster
# Out:
# array([[ 3.45984939,  6.01108807],
#        [11.60861104,  7.00586243]])

# %%
# VISUALISASI HASIL CLUSTERING
plt.scatter(ann_kmeans0, spend_kmeans0, s = 80, c = "#5F6F65", label = "Cluster 1")
plt.scatter(ann_kmeans1, spend_kmeans1, s = 80, c = "#808D7C", label = "Cluster 2")

# Centroid
plt.scatter(centroid_cluster[:, 0], centroid_cluster[:, 1], s = 160, c = "black", label = "Centroids")
plt.title("Clusters of Customers")
plt.xlabel("Genre")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# ## **Cluster = 6**

# %%
# Pakai cluster = 6
kmeans = KMeans(n_clusters = 6, random_state = 14)
kmeans.fit(clustering)
# Out:
# KMeans(n_clusters=6, random_state=14)

# %%
kmeans.labels_
# Out:
# array([3, 3, 3, ..., 5, 2, 2], dtype=int32)

# %%
hasil_kmeans = clustering.copy()
hasil_kmeans["cluster"] = kmeans.labels_
hasil_kmeans.head()
# Out:
#   name  amount  cluster
# 0    5     6.0        3
# 1    5     6.0        3
# 2    5     1.0        3
# 3    5     6.0        3
# 4    5     6.0        3

# %%
# Nilai untuk sumbu X dan Y
cluster_x = hasil_kmeans["cluster"].value_counts().index
cluster_y = hasil_kmeans["cluster"].value_counts().values

# Visualisasi
sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
plt.title("Frekuensi Data pada Masing-Masing Cluster (KMeans)")
plt.xlabel("Cluster")
plt.ylabel("Frekuensi")
# Out:
# <ipython-input-83-9773dc406189>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cluster_x, y=cluster_y, palette='viridis') # Changed to named arguments
# Text(0, 0.5, 'Frekuensi')

# %%
# Nilai fitur/variabel dari masing-masing cluster
ann_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 0]
spend_kmeans0 = hasil_kmeans[hasil_kmeans["cluster"] == 0].iloc[:, 1]
ann_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 0]
spend_kmeans1 = hasil_kmeans[hasil_kmeans["cluster"] == 1].iloc[:, 1]
ann_kmeans2 = hasil_kmeans[hasil_kmeans["cluster"] == 2].iloc[:, 0]
spend_kmeans2 = hasil_kmeans[hasil_kmeans["cluster"] == 2].iloc[:, 1]
ann_kmeans3 = hasil_kmeans[hasil_kmeans["cluster"] == 3].iloc[:, 0]
spend_kmeans3 = hasil_kmeans[hasil_kmeans["cluster"] == 3].iloc[:, 1]
ann_kmeans4 = hasil_kmeans[hasil_kmeans["cluster"] == 4].iloc[:, 0]
spend_kmeans4 = hasil_kmeans[hasil_kmeans["cluster"] == 4].iloc[:, 1]
ann_kmeans5 = hasil_kmeans[hasil_kmeans["cluster"] == 5].iloc[:, 0]
spend_kmeans5 = hasil_kmeans[hasil_kmeans["cluster"] == 5].iloc[:, 1]

# Pusat dari cluster (centroid)
centroid_cluster = kmeans.cluster_centers_
centroid_cluster
# Out:
# array([[ 1.6435329 ,  2.97017404],
#        [11.94200403,  8.31305032],
#        [ 3.27324106,  9.02677331],
#        [ 6.84420546,  3.27699165],
#        [12.5137857 ,  2.7947829 ],
#        [ 9.69802707, 14.38480352]])

# %%
# VISUALISASI HASIL CLUSTERING
plt.scatter(ann_kmeans0, spend_kmeans0, s = 80, c = "#5F6F65", label = "Cluster 1")
plt.scatter(ann_kmeans1, spend_kmeans1, s = 80, c = "#808D7C", label = "Cluster 2")
plt.scatter(ann_kmeans2, spend_kmeans2, s = 80, c = "#9CA986", label = "Cluster 3")
plt.scatter(ann_kmeans3, spend_kmeans3, s = 80, c = "#493628", label = "Cluster 4")
plt.scatter(ann_kmeans4, spend_kmeans4, s = 80, c = "#AB886D", label = "Cluster 5")
plt.scatter(ann_kmeans5, spend_kmeans5, s = 80, c = "#B7B7B7", label = "Cluster 6")

# Centroid
plt.scatter(centroid_cluster[:, 0], centroid_cluster[:, 1], s = 160, c = "black", label = "Centroids")
plt.title("Clusters of Customers")
plt.xlabel("Rental Duration")
plt.ylabel("Rental Rate")
plt.legend()
plt.show()
